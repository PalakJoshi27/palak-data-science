# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ###`Q-1:` Write a program to create an empty series.

# %%
a=[]
pd.Series(a)
# Out:
# Series([], dtype: object)

# %% [markdown]
# ###`Q-2:` Write a Pandas program to add, subtract, multiple and divide two Pandas Series.

# %%
a=pd.Series([1,2,3,4,5])
b=pd.Series([6,7,8,9,10])
print(a.add(b))
print(a.sub(b))
print(a.multiply(b))
print(a.divide(b))
# Out:
# 0     7
# 1     9
# 2    11
# 3    13
# 4    15
# dtype: int64
# 0   -5
# 1   -5
# 2   -5
# 3   -5
# 4   -5
# dtype: int64
# 0     6
# 1    14
# 2    24
# 3    36
# 4    50
# dtype: int64
# 0    0.166667
# 1    0.285714
# 2    0.375000
# 3    0.444444
# 4    0.500000
# dtype: float64

# %% [markdown]
# ###`Q-3` Write a Pandas program to compare the elements of the two Pandas Series.
# Sample Series: [2, 4, 6, 8, 10], [1, 3, 5, 7, 10]

# %%
a=pd.Series([2, 4, 6, 8, 10])
b=pd.Series([1, 3, 5, 7, 10])
print(a==b)
print(a>b)
print(a<b)
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# dtype: bool
# 0     True
# 1     True
# 2     True
# 3     True
# 4    False
# dtype: bool
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %% [markdown]
# ###`Q-5.`Write a function to change the data type of given a column or a Series. Function takes series and data type as input, returns the converted series.
# ```
# series = pd.Series([1,2,'Python', 2.0, True, 100])
# change to float type data
# ```
# Note: Read about pd.to_numeric()

# %%
series = pd.Series([1,2,'Python', 2.0, True, 100])
def change_dtype(series):
    return pd.to_numeric(series, errors='coerce')

new_series = change_dtype(series)
print(new_series)
# Out:
# 0      1.0
# 1      2.0
# 2      NaN
# 3      2.0
# 4      1.0
# 5    100.0
# dtype: float64

# %% [markdown]
# Download data - https://drive.google.com/file/d/1LRhXwbEodeWXtzPhJCX0X9Lf_BECzvqb/view?usp=share_link
# All Batsman runs series in IPL 2008 to 2022.
#
# Below questions are based on this data.

# %%
runs=pd.read_csv('batsman_runs_series.csv',index_col='batter').squeeze('columns')
runs
# Out:
# batter
# A Ashish Reddy     280
# A Badoni           161
# A Chandila           4
# A Chopra            53
# A Choudhary         25
#                   ...
# Yash Dayal           0
# Yashpal Singh       47
# Younis Khan          3
# Yuvraj Singh      2754
# Z Khan             117
# Name: batsman_run, Length: 605, dtype: int64

# %% [markdown]
# ###`Q-6` Find top 10 most run getter from the series.

# %%
runs.sort_values(ascending=False).head(10)
# Out:
# batter
# V Kohli           6634
# S Dhawan          6244
# DA Warner         5883
# RG Sharma         5881
# SK Raina          5536
# AB de Villiers    5181
# CH Gayle          4997
# MS Dhoni          4978
# RV Uthappa        4954
# KD Karthik        4377
# Name: batsman_run, dtype: int64

# %% [markdown]
# ###`Q-7` No of players having runs above 3000

# %%
runs[runs>3000].count()
# Out:
# np.int64(20)

# %% [markdown]
# ###`Q-8` No of players having runs above mean value?

# %%
runs[runs>runs.mean()].count()
# Out:
# np.int64(128)
