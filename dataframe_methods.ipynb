# %%
import numpy as np
import pandas as pd

# %%
#value_counts(series and dataframe
 #freq of a row

# %%
ipl = pd.read_csv('/content/IPL_Matches_2008_2022.csv')
ipl.head(2)
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
#
#                          Team1             Team2  \
# 0             Rajasthan Royals    Gujarat Titans
# 1  Royal Challengers Bangalore  Rajasthan Royals
#
#                               Venue        TossWinner TossDecision SuperOver  \
# 0  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals          bat         N
# 1  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals        field         N
#
#         WinningTeam    WonBy  Margin method Player_of_Match  \
# 0    Gujarat Titans  Wickets     7.0    NaN       HH Pandya
# 1  Rajasthan Royals  Wickets     7.0    NaN      JC Buttler
#
#                                         Team1Players  \
# 0  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
#
# ...

# %%
#find which player has won most 'potm'in finals and qualifiers
ipl[~ipl['MatchNumber'].str.isdigit()]['Player_of_Match'].value_counts()
# Out:
# Player_of_Match
# F du Plessis         3
# SK Raina             3
# KA Pollard           3
# JJ Bumrah            2
# AB de Villiers       2
# MK Pandey            2
# M Vijay              2
# A Kumble             2
# YK Pathan            2
# SR Watson            2
# HH Pandya            1
# RM Patidar           1
# JC Buttler           1
# RR Pant              1
# KS Williamson        1
# MP Stoinis           1
# TA Boult             1
# SP Narine            1
# RD Gaikwad           1
# VR Iyer              1
# DA Miller            1
# Washington Sundar    1
# NM Coulter-Nile      1
# KV Sharma            1
# BCJ Cutting          1
# KH Pandya            1
# SA Yadav             1
# Rashid Khan          1
# AD Russell           1
# RG Sharma            1
# A Nehra              1
# DA Warner            1
# MC Henriques         1
# Harbhajan Singh      1
# BJ Hodge             1
# UT Yadav             1
# V Sehwag             1
# MS Bisla             1
# MEK Hussey           1
# ...

# %%
#toss decision plot
ipl['TossDecision'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
#how many matches each team has played
(ipl['Team1'].value_counts()+ ipl['Team2'].value_counts()).sort_values(ascending=False)
# Out:
# Mumbai Indians                 231
# Royal Challengers Bangalore    226
# Kolkata Knight Riders          223
# Chennai Super Kings            208
# Rajasthan Royals               192
# Kings XI Punjab                190
# Delhi Daredevils               161
# Sunrisers Hyderabad            152
# Deccan Chargers                 75
# Delhi Capitals                  63
# Pune Warriors                   46
# Gujarat Lions                   30
# Punjab Kings                    28
# Gujarat Titans                  16
# Rising Pune Supergiant          16
# Lucknow Super Giants            15
# Kochi Tuskers Kerala            14
# Rising Pune Supergiants         14
# Name: count, dtype: int64

# %%
#sort_vaues
movie=pd.read_csv('movies.csv')
movie
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
movie.sort_values('poster_path') #in this all the nan values go down
# Out:
#                               title_x    imdb_id  \
# 1254         Hazaaron Khwaishein Aisi  tt0411469
# 235                    Ranchi Diaries  tt7154994
# 312                           M Cream  tt2963974
# 1491                           Kaante  tt0294662
# 438              Meeruthiya Gangsters  tt4117066
# ...                               ...        ...
# 1602              Ittefaq (2001 film)  tt0297983
# 1603                Mitti (2001 film)  tt0446159
# 1606  Hadh: Life on the Edge of Death  tt0396044
# 1617              Officer (2001 film)  tt0265452
# 1626                  Sabse Bada Sukh  tt0069204
#
#                                             poster_path  \
# 1254  https://upload.wikimedia.org/wikipedia/commons...
# 235   https://upload.wikimedia.org/wikipedia/commons...
# 312   https://upload.wikimedia.org/wikipedia/commons...
# 1491  https://upload.wikimedia.org/wikipedia/commons...
# 438   https://upload.wikimedia.org/wikipedia/commons...
# ...

# %%
movie.sort_values(['year_of_release','title_x'])
# Out:
#                                      imdb_id  \
# title_x
# Aalavandhan                        tt0294264
# Aamdani Atthanni Kharcha Rupaiya   tt0305173
# Aashiq (2001 film)                 tt0273406
# Ajnabee (2001 film)                tt0278291
# Aks (2001 film)                    tt0289845
# ...                                      ...
# Ujda Chaman                       tt11046300
# Uri: The Surgical Strike           tt8291224
# Why Cheat India                    tt8108208
# Yaaram (2019 film)                tt11007050
# Yeh Saali Aashiqui                tt10443846
#
#                                                                         poster_path  \
# title_x
# Aalavandhan                       https://upload.wikimedia.org/wikipedia/en/thum...
# Aamdani Atthanni Kharcha Rupaiya  https://upload.wikimedia.org/wikipedia/en/thum...
# Aashiq (2001 film)                https://upload.wikimedia.org/wikipedia/en/c/c6...
# ...

# %%
#if we want movies name in desc order
movie.sort_values(['year_of_release','title_x'],ascending=[False,True])
# Out:
#                                          imdb_id  \
# title_x
# 22 Yards                               tt9496212
# Albert Pinto Ko Gussa Kyun Aata Hai?   tt4355838
# Amavas                                 tt8396186
# Arjun Patiala                          tt7881524
# Article 15 (film)                     tt10324144
# ...                                          ...
# Yaadein (2001 film)                    tt0248617
# Yeh Raaste Hain Pyaar Ke               tt0292740
# Yeh Teraa Ghar Yeh Meraa Ghar          tt0298606
# Yeh Zindagi Ka Safar                   tt0298607
# Zubeidaa                               tt0255713
#
#                                                                             poster_path  \
# title_x
# 22 Yards                              https://upload.wikimedia.org/wikipedia/en/thum...
# Albert Pinto Ko Gussa Kyun Aata Hai?  https://upload.wikimedia.org/wikipedia/en/thum...
# Amavas                                https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
#rank(series)
runs= pd.read_csv('/content/batsman_runs_series.csv')
runs.head()
# Out:
#            batter  batsman_run
# 0  A Ashish Reddy          280
# 1        A Badoni          161
# 2      A Chandila            4
# 3        A Chopra           53
# 4     A Choudhary           25

# %%
runs['batting_rank']=runs['batsman_run'].rank(ascending=False)
runs.sort_values('batting_rank')
# Out:
#              batter  batsman_run  batting_rank
# 569         V Kohli         6634           1.0
# 462        S Dhawan         6244           2.0
# 130       DA Warner         5883           3.0
# 430       RG Sharma         5881           4.0
# 493        SK Raina         5536           5.0
# ..              ...          ...           ...
# 570  V Pratap Singh            0         594.0
# 63     Abdur Razzak            0         594.0
# 562          U Kaul            0         594.0
# 65       Akash Deep            0         594.0
# 57           AS Roy            0         594.0
#
# [605 rows x 3 columns]

# %%
#sort_index(series and datframe)
movie.sort_index(ascending=False)
# Out:
#                             imdb_id  \
# title_x
# Zubeidaa                  tt0255713
# Zor Lagaa Ke...Haiya!     tt1479857
# Zokkomon                  tt1605790
# Zindagi Tere Naam         tt2164702
# Zindagi Na Milegi Dobara  tt1562872
# ...                             ...
# 1971 (2007 film)          tt0983990
# 1920: The Evil Returns    tt2222550
# 1920: London              tt5638500
# 1920 (film)               tt1301698
# 16 December (film)        tt0313844
#
#                                                                 poster_path  \
# title_x
# Zubeidaa                  https://upload.wikimedia.org/wikipedia/en/thum...
# Zor Lagaa Ke...Haiya!     https://upload.wikimedia.org/wikipedia/en/thum...
# Zokkomon                  https://upload.wikimedia.org/wikipedia/en/thum...
# Zindagi Tere Naam         https://upload.wikimedia.org/wikipedia/en/thum...
# Zindagi Na Milegi Dobara  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
#set_index
runs.set_index('batter',inplace=True)
runs
# Out:
#                 batsman_run  batting_rank
# batter
# A Ashish Reddy          280         166.5
# A Badoni                161         226.0
# A Chandila                4         535.0
# A Chopra                 53         329.0
# A Choudhary              25         402.5
# ...                     ...           ...
# Yash Dayal                0         594.0
# Yashpal Singh            47         343.0
# Younis Khan               3         547.5
# Yuvraj Singh           2754          27.0
# Z Khan                  117         256.0
#
# [605 rows x 2 columns]

# %%
#reset_index(series + dataframe)
runs.reset_index(inplace=True)
runs
# Out:
#              batter  batsman_run  batting_rank
# 0    A Ashish Reddy          280         166.5
# 1          A Badoni          161         226.0
# 2        A Chandila            4         535.0
# 3          A Chopra           53         329.0
# 4       A Choudhary           25         402.5
# ..              ...          ...           ...
# 600      Yash Dayal            0         594.0
# 601   Yashpal Singh           47         343.0
# 602     Younis Khan            3         547.5
# 603    Yuvraj Singh         2754          27.0
# 604          Z Khan          117         256.0
#
# [605 rows x 3 columns]

# %%
#how to replace existing index w/o losing
runs.reset_index().set_index('batting_rank')
# Out:
#               index          batter  batsman_run
# batting_rank
# 166.5             0  A Ashish Reddy          280
# 226.0             1        A Badoni          161
# 535.0             2      A Chandila            4
# 329.0             3        A Chopra           53
# 402.5             4     A Choudhary           25
# ...             ...             ...          ...
# 594.0           600      Yash Dayal            0
# 343.0           601   Yashpal Singh           47
# 547.5           602     Younis Khan            3
# 27.0            603    Yuvraj Singh         2754
# 256.0           604          Z Khan          117
#
# [605 rows x 3 columns]

# %%
#series to dataframe using reset_index

# %%
#rename(dataframe)-> index
movie.set_index('title_x',inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-197/163620730.py in <cell line: 0>()
#       1 #rename(dataframe)-> index
# ----> 2 movie.set_index('title_x',inplace=True)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    6120
#    6121         if missing:
# -> 6122             raise KeyError(f"None of {missing} are in the columns")
#    6123
#    6124         if inplace:
#
# KeyError: "None of ['title_x'] are in the columns"

# %%
movie.rename(columns={'imdb_id':'imdb','poster_path':'link'})
# Out:
#                                             imdb  \
# title_x
# Uri: The Surgical Strike               tt8291224
# Battalion 609                          tt9472208
# The Accidental Prime Minister (film)   tt6986710
# Why Cheat India                        tt8108208
# Evening Shadows                        tt6028796
# ...                                          ...
# Tera Mera Saath Rahen                  tt0301250
# Yeh Zindagi Ka Safar                   tt0298607
# Sabse Bada Sukh                        tt0069204
# Daaka                                 tt10833860
# Humsafar                               tt2403201
#
#                                                                                    link  \
# title_x
# Uri: The Surgical Strike              https://upload.wikimedia.org/wikipedia/en/thum...
# Battalion 609                                                                       NaN
# The Accidental Prime Minister (film)  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
movie.rename(index={'Uri: The Surgical Strike':'uri'})
# Out:
#                                          imdb_id  \
# title_x
# uri                                    tt8291224
# Battalion 609                          tt9472208
# The Accidental Prime Minister (film)   tt6986710
# Why Cheat India                        tt8108208
# Evening Shadows                        tt6028796
# ...                                          ...
# Tera Mera Saath Rahen                  tt0301250
# Yeh Zindagi Ka Safar                   tt0298607
# Sabse Bada Sukh                        tt0069204
# Daaka                                 tt10833860
# Humsafar                               tt2403201
#
#                                                                             poster_path  \
# title_x
# uri                                   https://upload.wikimedia.org/wikipedia/en/thum...
# Battalion 609                                                                       NaN
# The Accidental Prime Minister (film)  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
#unique(series)

# %%
#nunique(series+dataframe) doesn't count nan
ipl['Season'].nunique()
# Out:
# 15

# %%
#isnull(series+dataframe)

# %%
#notnull

# %%
#hasnans(series)
movie['tagline'].hasnans
# Out:
# True

# %%
#dropna(series+dataframe)
movie.dropna() #it will remove the row that contain missing val
# Out:
#                             imdb_id  \
# title_x
# Gully Boy                 tt2395469
# Yeh Hai India             tt5525846
# Article 15 (film)        tt10324144
# Aiyaary                   tt6774212
# Raid (2018 film)          tt7363076
# ...                             ...
# Kasoor                    tt0272688
# Maya (2001 film)          tt0299027
# Nayak (2001 Hindi film)   tt0291376
# Tum Bin                   tt0290326
# Zubeidaa                  tt0255713
#
#                                                                poster_path  \
# title_x
# Gully Boy                https://upload.wikimedia.org/wikipedia/en/thum...
# Yeh Hai India            https://upload.wikimedia.org/wikipedia/en/thum...
# Article 15 (film)        https://upload.wikimedia.org/wikipedia/en/thum...
# Aiyaary                  https://upload.wikimedia.org/wikipedia/en/thum...
# Raid (2018 film)         https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
movie.dropna(how='all')
# Out:
#                                          imdb_id  \
# title_x
# Uri: The Surgical Strike               tt8291224
# Battalion 609                          tt9472208
# The Accidental Prime Minister (film)   tt6986710
# Why Cheat India                        tt8108208
# Evening Shadows                        tt6028796
# ...                                          ...
# Tera Mera Saath Rahen                  tt0301250
# Yeh Zindagi Ka Safar                   tt0298607
# Sabse Bada Sukh                        tt0069204
# Daaka                                 tt10833860
# Humsafar                               tt2403201
#
#                                                                             poster_path  \
# title_x
# Uri: The Surgical Strike              https://upload.wikimedia.org/wikipedia/en/thum...
# Battalion 609                                                                       NaN
# The Accidental Prime Minister (film)  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
movie.dropna(subset=['tagline'])
# Out:
#                              imdb_id  \
# title_x
# Bombairiya                 tt4971258
# Gully Boy                  tt2395469
# Total Dhamaal              tt7639372
# Mere Pyare Prime Minister  tt8207768
# Yeh Hai India              tt5525846
# ...                              ...
# Maya (2001 film)           tt0299027
# Nayak (2001 Hindi film)    tt0291376
# Yeh Raaste Hain Pyaar Ke   tt0292740
# Tum Bin                    tt0290326
# Zubeidaa                   tt0255713
#
#                                                                  poster_path  \
# title_x
# Bombairiya                 https://upload.wikimedia.org/wikipedia/en/thum...
# Gully Boy                  https://upload.wikimedia.org/wikipedia/en/thum...
# Total Dhamaal              https://upload.wikimedia.org/wikipedia/en/thum...
# Mere Pyare Prime Minister  https://upload.wikimedia.org/wikipedia/en/thum...
# Yeh Hai India              https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
#fillna(series+dataframe)
movie['tagline'].fillna('unknown')
# Out:
# title_x
# Uri: The Surgical Strike                unknown
# Battalion 609                           unknown
# The Accidental Prime Minister (film)    unknown
# Why Cheat India                         unknown
# Evening Shadows                         unknown
#                                          ...
# Tera Mera Saath Rahen                   unknown
# Yeh Zindagi Ka Safar                    unknown
# Sabse Bada Sukh                         unknown
# Daaka                                   unknown
# Humsafar                                unknown
# Name: tagline, Length: 1629, dtype: object
